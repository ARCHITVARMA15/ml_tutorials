# %%
import pandas as pd
import numpy as np

# %%
#Label Encoding - Ordinal Encoding 
#Label Encoder - for Y or ouput 
#Ordinal Encoder - for X or input features
df = pd.read_csv('customer.csv')

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 0    30  Female  Average    School        No
# 20   57  Female  Average    School       Yes
# 27   69  Female     Poor        PG        No
# 28   48    Male     Poor    School        No
# 29   83  Female  Average        UG       Yes

# %%
# all the categorical columns except the first two columns
df = df.iloc[:,2:]

# %%
df.head()
# Out:
#   purchased
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,0:2], df.iloc[:,-1], test_size=0.2)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X_train
# Out:
#    purchased
# 17       Yes
# 37       Yes
# 1         No
# 36       Yes
# 34        No
# 29       Yes
# 44        No
# 14       Yes
# 47       Yes
# 48       Yes
# 2         No
# 12        No
# 10       Yes
# 25        No
# 3         No
# 38        No
# 4         No
# 15        No
# 23        No
# 18        No
# 27        No
# 0         No
# 49        No
# 21        No
# 33       Yes
# 40        No
# 5        Yes
# 45       Yes
# 39        No
# 19       Yes
# 11       Yes
# 22       Yes
# 35       Yes
# 43        No
# 16       Yes
# 7        Yes
# 31       Yes
# 26        No
# 28        No
# 6         No

# %%
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 oe.fit(X_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/preprocessing/_encoders.py:1515, in OrdinalEncoder.fit(self, X, y)
#    1508     raise TypeError(
#    1509         "unknown_value should only be set when "
#    1510         "handle_unknown is 'use_encoded_value', "
#    1511         f"got {self.unknown_value}."
#    1512     )
#    1514 # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> 1515 fit_results = self._fit(
#    1516     X,
#    1517     handle_unknown=self.handle_unknown,
#    1518     ensure_all_finite="allow-nan",
#    1519     return_and_ignore_missing_for_infrequent=True,
#    1520 )
#    1521 self._missing_indices = fit_results["missing_indices"]
#    1523 cardinalities = [len(categories) for categories in self.categories_]
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/preprocessing/_encoders.py:90, in _BaseEncoder._fit(self, X, handle_unknown, ensure_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#      88 if self.categories != "auto":
#      89     if len(self.categories) != n_features:
# ---> 90         raise ValueError(
#      91             "Shape mismatch: if categories is an array,"
#      92             " it has to be of shape (n_features,)."
#      93         )
#      95 self.categories_ = []
#      96 category_counts = []
#
# ValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,).

# %%
# X_train = oe.transform(X_train)
# X_test_encoded = oe.transform(X_test)
X_train = oe.transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 # X_train = oe.transform(X_train)
#       2 # X_test_encoded = oe.transform(X_test)
# ----> 3 X_train = oe.transform(X_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/preprocessing/_encoders.py:1601, in OrdinalEncoder.transform(self, X)
#    1583 """
#    1584 Transform X to ordinal codes.
#    1585
#    (...)   1594     Transformed input.
#    1595 """
#    1596 check_is_fitted(self, "categories_")
#    1597 X_int, X_mask = self._transform(
#    1598     X,
#    1599     handle_unknown=self.handle_unknown,
#    1600     ensure_all_finite="allow-nan",
# -> 1601     ignore_category_indices=self._missing_indices,
#    1602 )
#    1603 X_trans = X_int.astype(self.dtype, copy=False)
#    1605 for cat_idx, missing_idx in self._missing_indices.items():
#
# AttributeError: 'OrdinalEncoder' object has no attribute '_missing_indices'

# %%
X_train
# Out:
#    purchased
# 17       Yes
# 37       Yes
# 1         No
# 36       Yes
# 34        No
# 29       Yes
# 44        No
# 14       Yes
# 47       Yes
# 48       Yes
# 2         No
# 12        No
# 10       Yes
# 25        No
# 3         No
# 38        No
# 4         No
# 15        No
# 23        No
# 18        No
# 27        No
# 0         No
# 49        No
# 21        No
# 33       Yes
# 40        No
# 5        Yes
# 45       Yes
# 39        No
# 19       Yes
# 11       Yes
# 22       Yes
# 35       Yes
# 43        No
# 16       Yes
# 7        Yes
# 31       Yes
# 26        No
# 28        No
# 6         No
