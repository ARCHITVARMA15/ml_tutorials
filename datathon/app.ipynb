# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ps 3.csv")

# %%
df.head()
# Out:
#     ID        Age Education_Level Years_of_Experience Current_or_Target_Role  \
# 0  0x1        NaN         Diploma                 0.6  Cybersecurity Analyst
# 1    2        NaN             NaN                 8.4                      ?
# 2    3        NaN        Bachelor            7.3-12.3           tsylanA ataD
# 3    4  {"v": 25}         Diploma                11.2                    NaN
# 4  0x5         38         MISSING                 0.4                    NaN
#
#   Technical_Skill_Score Soft_Skill_Score Domain_Knowledge_Score  \
# 0                    61            51-56                     65
# 1             {"v": 59}          MISSING                MISSING
# 2                    48        {"v": 57}                     92
# 3                    49            42-47              {"v": 94}
# 4                   NaN               66                     66
#
#   Certification_Count Training_Hours_Last_Year Skill_Gap_Score  \
# ...

# %%
df.sample(5)
# Out:
#            ID     Age Education_Level Years_of_Experience  \
# 29504  0x7341       ?     High School                 1.3
# 33002  0x80eb   47-52             PhD                 NaN
# 16829  0x41be      29    RGlwbG9tYQ==          {"v": 7.0}
# 32157   32158   40-45    RGlwbG9tYQ==             Val_9.1
# 14570  0x38eb  Val_29          retsaM                 0.7
#
#       Current_or_Target_Role Technical_Skill_Score Soft_Skill_Score  \
# 29504         Cloud Engineer                   NaN              NaN
# 33002         Cloud Engineer                    56               41
# 16829            ML Engineer                    55              NaN
# 32157      Software Engineer                   NaN               56
# 14570                MISSING                   NaN               63
#
#       Domain_Knowledge_Score Certification_Count Training_Hours_Last_Year  \
# 29504                     48            {"v": 0}                       82
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        50000 non-null  object
#  1   Age                       43907 non-null  object
#  2   Education_Level           43984 non-null  object
#  3   Years_of_Experience       43923 non-null  object
#  4   Current_or_Target_Role    43992 non-null  object
#  5   Technical_Skill_Score     44121 non-null  object
#  6   Soft_Skill_Score          43954 non-null  object
#  7   Domain_Knowledge_Score    44089 non-null  object
#  8   Certification_Count       43940 non-null  object
#  9   Training_Hours_Last_Year  43979 non-null  object
#  10  Skill_Gap_Score           44029 non-null  object
#  11  Readiness_Score           43930 non-null  object
#  12  Employment_Status         44045 non-null  object
# ...

# %%
df.describe()
# Out:
#            ID      Age Education_Level Years_of_Experience  \
# count   50000    43907           43984               43923
# unique  50000      170              17                1076
# top       0x1  MISSING     High School                   ?
# freq        1     2022            4803                2061
#
#        Current_or_Target_Role Technical_Skill_Score Soft_Skill_Score  \
# count                   43992                 44121            43954
# unique                     23                   242              242
# top         Software Engineer               MISSING                ?
# freq                     3501                  1979             2022
#
#        Domain_Knowledge_Score Certification_Count Training_Hours_Last_Year  \
# count                   44089               43940                    43979
# unique                    242                  34                     2002
# top                         ?                   2                        ?
# ...

# %%
df.isna().sum()
# Out:
# ID                             0
# Age                         6093
# Education_Level             6016
# Years_of_Experience         6077
# Current_or_Target_Role      6008
# Technical_Skill_Score       5879
# Soft_Skill_Score            6046
# Domain_Knowledge_Score      5911
# Certification_Count         6060
# Training_Hours_Last_Year    6021
# Skill_Gap_Score             5971
# Readiness_Score             6070
# Employment_Status           5955
# Industry                    6061
# Annual_Salary_USD           5927
# Career_Readiness_Level      6009
# dtype: int64

# %%
df.head()
# Out:
# 0    <bound method Series.mean of 0              Na...
# 1    <bound method Series.mean of 0              Na...
# 2    <bound method Series.mean of 0              Na...
# 3                                            {"v": 25}
# 4                                                   38
# Name: Age, dtype: object

# %%
df.head()
# Out:
# 0    <bound method Series.mean of 0              Na...
# 1    <bound method Series.mean of 0              Na...
# 2    <bound method Series.mean of 0              Na...
# 3                                            {"v": 25}
# 4                                                   38
# Name: Age, dtype: object
