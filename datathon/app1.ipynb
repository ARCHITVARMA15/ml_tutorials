# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ps 3.csv")

# %%
df.head()
# Out:
#     ID        Age Education_Level Years_of_Experience Current_or_Target_Role  \
# 0  0x1        NaN         Diploma                 0.6  Cybersecurity Analyst
# 1    2        NaN             NaN                 8.4                      ?
# 2    3        NaN        Bachelor            7.3-12.3           tsylanA ataD
# 3    4  {"v": 25}         Diploma                11.2                    NaN
# 4  0x5         38         MISSING                 0.4                    NaN
#
#   Technical_Skill_Score Soft_Skill_Score Domain_Knowledge_Score  \
# 0                    61            51-56                     65
# 1             {"v": 59}          MISSING                MISSING
# 2                    48        {"v": 57}                     92
# 3                    49            42-47              {"v": 94}
# 4                   NaN               66                     66
#
#   Certification_Count Training_Hours_Last_Year Skill_Gap_Score  \
# ...

# %%
df.sample(5)
# Out:
#            ID      Age Education_Level Years_of_Experience  \
# 20638  0x509f       20         Diploma            9.8-14.8
# 14825   14826      NaN    QmFjaGVsb3I=                24.8
# 42043  0xa43c      NaN        TWFzdGVy                 0.4
# 36614   36615       19          Master                 7.2
# 7191     7192  MISSING    QmFjaGVsb3I=             MISSING
#
#       Current_or_Target_Role Technical_Skill_Score Soft_Skill_Score  \
# 20638      Software Engineer                    78                ?
# 14825      Software Engineer                Val_60        {"v": 94}
# 42043                    NaN                Val_84           Val_77
# 36614           System Admin                    74               77
# 7191            Data Analyst                    72               61
#
#       Domain_Knowledge_Score Certification_Count Training_Hours_Last_Year  \
# 20638                      ?               Val_3                      471
# ...

# %%
df['Age'].fillna(0)
# Out:
# 0                0
# 1                0
# 2                0
# 3        {"v": 25}
# 4               38
#            ...
# 49995            0
# 49996           34
# 49997            0
# 49998        41-46
# 49999           26
# Name: Age, Length: 50000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        50000 non-null  object
#  1   Age                       43907 non-null  object
#  2   Education_Level           43984 non-null  object
#  3   Years_of_Experience       43923 non-null  object
#  4   Current_or_Target_Role    43992 non-null  object
#  5   Technical_Skill_Score     44121 non-null  object
#  6   Soft_Skill_Score          43954 non-null  object
#  7   Domain_Knowledge_Score    44089 non-null  object
#  8   Certification_Count       43940 non-null  object
#  9   Training_Hours_Last_Year  43979 non-null  object
#  10  Skill_Gap_Score           44029 non-null  object
#  11  Readiness_Score           43930 non-null  object
#  12  Employment_Status         44045 non-null  object
# ...

# %%
df.describe()
# Out:
#            ID      Age Education_Level Years_of_Experience  \
# count   50000    43907           43984               43923
# unique  50000      170              17                1076
# top       0x1  MISSING     High School                   ?
# freq        1     2022            4803                2061
#
#        Current_or_Target_Role Technical_Skill_Score Soft_Skill_Score  \
# count                   43992                 44121            43954
# unique                     23                   242              242
# top         Software Engineer               MISSING                ?
# freq                     3501                  1979             2022
#
#        Domain_Knowledge_Score Certification_Count Training_Hours_Last_Year  \
# count                   44089               43940                    43979
# unique                    242                  34                     2002
# top                         ?                   2                        ?
# ...

# %%
df.isna().sum()
# Out:
# ID                             0
# Age                         6093
# Education_Level             6016
# Years_of_Experience         6077
# Current_or_Target_Role      6008
# Technical_Skill_Score       5879
# Soft_Skill_Score            6046
# Domain_Knowledge_Score      5911
# Certification_Count         6060
# Training_Hours_Last_Year    6021
# Skill_Gap_Score             5971
# Readiness_Score             6070
# Employment_Status           5955
# Industry                    6061
# Annual_Salary_USD           5927
# Career_Readiness_Level      6009
# dtype: int64

# %%
df=pd.get_dummies(df, columns=['Career_Readiness_Level'],dtype=int,drop_first=True)

# %%
df.head()
# Out:
#     ID        Age Education_Level Years_of_Experience Current_or_Target_Role  \
# 0  0x1        NaN         Diploma                 0.6  Cybersecurity Analyst
# 1    2        NaN             NaN                 8.4                      ?
# 2    3        NaN        Bachelor            7.3-12.3           tsylanA ataD
# 3    4  {"v": 25}         Diploma                11.2                    NaN
# 4  0x5         38         MISSING                 0.4                    NaN
#
#   Technical_Skill_Score Soft_Skill_Score Domain_Knowledge_Score  \
# 0                    61            51-56                     65
# 1             {"v": 59}          MISSING                MISSING
# 2                    48        {"v": 57}                     92
# 3                    49            42-47              {"v": 94}
# 4                   NaN               66                     66
#
#   Certification_Count Training_Hours_Last_Year  ...  \
# 0                   0                      310  ...
# ...

# %%
df.drop(columns=['Career_Readiness_Level_MISSING','Career_Readiness_Level_SGlnaA==','Career_Readiness_Level_TG93','Career_Readiness_Level_TWVkaXVt'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.drop(columns=['Career_Readiness_Level_MISSING','Career_Readiness_Level_SGlnaA==','Career_Readiness_Level_TG93','Career_Readiness_Level_TWVkaXVt'],inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
# ...

# %%
df.drop(columns=['Career_Readiness_Level_MISSING','Career_Readiness_Level_SGlnaA==','Career_Readiness_Level_TG93','Career_Readiness_Level_TWVkaXVt'], inplace=True)

# %%
df
# Out:
#           ID        Age   Education_Level Years_of_Experience  \
# 0        0x1        NaN           Diploma                 0.6
# 1          2        NaN               NaN                 8.4
# 2          3        NaN          Bachelor            7.3-12.3
# 3          4  {"v": 25}           Diploma                11.2
# 4        0x5         38           MISSING                 0.4
# ...      ...        ...               ...                 ...
# 49995  49996        NaN  SGlnaCBTY2hvb2w=                 0.1
# 49996  49997         34                 ?            Val_17.3
# 49997  49998        NaN            Master                 NaN
# 49998  49999      41-46      QmFjaGVsb3I=             3.0-8.0
# 49999  50000         26               NaN                 1.3
#
#       Current_or_Target_Role Technical_Skill_Score Soft_Skill_Score  \
# 0      Cybersecurity Analyst                    61            51-56
# 1                          ?             {"v": 59}          MISSING
# ...

# %%
df
