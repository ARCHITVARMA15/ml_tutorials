# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('dataset2.clean.csv')

# %%
df.head()
# Out:
#   ID  Age Education_Level Years_of_Experience Current_or_Target_Role  \
# 0  1  NaN         Diploma                 0.6  Cybersecurity Analyst
# 1  2  NaN             NaN                 8.4                      ?
# 2  3  NaN        Bachelor            7.3-12.3           Data Analyst
# 3  4   25         Diploma                11.2                    NaN
# 4  5   38             NaN                 0.4                    NaN
#
#   Technical_Skill_Score Soft_Skill_Score Domain_Knowledge_Score  \
# 0                    61            51-56                     65
# 1                    59              NaN                    NaN
# 2                    48               57                     92
# 3                    49            42-47                     94
# 4                   NaN               66                     66
#
#   Certification_Count Training_Hours_Last_Year Skill_Gap_Score  \
# 0                   0                      310           41.87
# ...

# %%
df['Age'].fillna(df['Age'].mean)
# Out:
# 0        <bound method Series.mean of 0          NaN\n1...
# 1        <bound method Series.mean of 0          NaN\n1...
# 2        <bound method Series.mean of 0          NaN\n1...
# 3                                                       25
# 4                                                       38
#                                ...
# 49995    <bound method Series.mean of 0          NaN\n1...
# 49996                                                   34
# 49997    <bound method Series.mean of 0          NaN\n1...
# 49998                                                41-46
# 49999                                                   26
# Name: Age, Length: 50000, dtype: object

# %%
df.head()
# Out:
#   ID  Age Education_Level Years_of_Experience Current_or_Target_Role  \
# 0  1  NaN         Diploma                 0.6  Cybersecurity Analyst
# 1  2  NaN             NaN                 8.4                      ?
# 2  3  NaN        Bachelor            7.3-12.3           Data Analyst
# 3  4   25         Diploma                11.2                    NaN
# 4  5   38             NaN                 0.4                    NaN
#
#   Technical_Skill_Score Soft_Skill_Score Domain_Knowledge_Score  \
# 0                    61            51-56                     65
# 1                    59              NaN                    NaN
# 2                    48               57                     92
# 3                    49            42-47                     94
# 4                   NaN               66                     66
#
#   Certification_Count Training_Hours_Last_Year Skill_Gap_Score  \
# 0                   0                      310           41.87
# ...

# %%
df.describe()
# Out:
#               ID    Age Education_Level Years_of_Experience  \
# count      50000  41885           41983               41964
# unique     47891     85              15                 599
# top     1.00E+06      ?         Diploma                   ?
# freq           3   1935            5548                2061
#
#        Current_or_Target_Role Technical_Skill_Score Soft_Skill_Score  \
# count                   42018                 42142            41989
# unique                     15                   121              121
# top     Cybersecurity Analyst                     ?                ?
# freq                     4103                  1944             2022
#
#        Domain_Knowledge_Score Certification_Count Training_Hours_Last_Year  \
# count                   42183               41959                    42015
# unique                    121                  17                     1001
# top                         ?                   2                        ?
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of           ID    Age   Education_Level Years_of_Experience  \
# 0          1    NaN           Diploma                 0.6
# 1          2    NaN               NaN                 8.4
# 2          3    NaN          Bachelor            7.3-12.3
# 3          4     25           Diploma                11.2
# 4          5     38               NaN                 0.4
# ...      ...    ...               ...                 ...
# 49995  49996    NaN  SGlnaCBTY2hvb2w=                 0.1
# 49996  49997     34                 ?                17.3
# 49997  49998    NaN            Master                 NaN
# 49998  49999  41-46      QmFjaGVsb3I=             3.0-8.0
# 49999  50000     26               NaN                 1.3
#
#       Current_or_Target_Role Technical_Skill_Score Soft_Skill_Score  \
# 0      Cybersecurity Analyst                    61            51-56
# 1                          ?                    59              NaN
# ...

# %%
df = pd.get_dummies(df, columns=['Career_Readiness_Level'],dtype=int,drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df = pd.get_dummies(df, columns=['Career_Readiness_Level'],dtype=int,drop_first=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/reshape/encoding.py:170, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     168     raise TypeError("Input must be a list-like for parameter `columns`")
#     169 else:
# --> 170     data_to_encode = data[columns]
#     172 # validate prefixes and separator to avoid silently dropping cols
#     173 def check_len(item, name: str):
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# ...

# %%
df.head()
# Out:
#   ID Age Education_Level Years_of_Experience Current_or_Target_Role  \
# 0  1   ?         Diploma                 0.6  Cybersecurity Analyst
# 1  2   ?             NaN                 8.4                      ?
# 2  3   ?        Bachelor            7.3-12.3           Data Analyst
# 3  4  25         Diploma                11.2                    NaN
# 4  5  38             NaN                 0.4                    NaN
#
#   Technical_Skill_Score Soft_Skill_Score Domain_Knowledge_Score  \
# 0                    61            51-56                     65
# 1                    59              NaN                    NaN
# 2                    48               57                     92
# 3                    49            42-47                     94
# 4                   NaN               66                     66
#
#   Certification_Count Training_Hours_Last_Year  ... Readiness_Score  \
# 0                   0                      310  ...           47.35
# ...

# %%
df.head()
# Out:
#   ID Age Education_Level Years_of_Experience Current_or_Target_Role  \
# 0  1   ?         Diploma                 0.6  Cybersecurity Analyst
# 1  2   ?             NaN                 8.4                      ?
# 2  3   ?        Bachelor            7.3-12.3           Data Analyst
# 3  4  25         Diploma                11.2                    NaN
# 4  5  38             NaN                 0.4                    NaN
#
#   Technical_Skill_Score Soft_Skill_Score Domain_Knowledge_Score  \
# 0                    61            51-56                     65
# 1                    59              NaN                    NaN
# 2                    48               57                     92
# 3                    49            42-47                     94
# 4                   NaN               66                     66
#
#   Certification_Count Training_Hours_Last_Year Skill_Gap_Score  \
# 0                   0                      310           41.87
# ...
