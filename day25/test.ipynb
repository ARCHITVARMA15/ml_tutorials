# %%
#normalisation - to eliminate the unit, and talk only in magnitude of the value and that too on a common scale

# %%
#Min max Scaling - (X-Xmin)/(Xmax-Xmin) ->[0,1]
#Standardisation - (X-mean)/std ->[-inf, +inf] (Gaussian Distribution)
#Robust Scaling - (X-median)/IQR ->[-inf, +inf] (not affected by outliers)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset2.clean.csv',header=None,usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']

# %%
df
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
color_dict={1:"red", 3:'green',2:'blue'}
sns.scatterplot(x=df["Alcohol"], y =df['Malic acid'], hue=df['Class label'],palette = color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class label', axis=1),
                                                    df['Class label'],
                                                    test_size=0.3,
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

#fit the scaler only to the train data 
scaler.fit(X_train)

#transform both train and test data 
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
np.round(X_train.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6

# %%
np.round(X_train_scaled.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.2
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Alcohol'], X_train['Malic acid'],c=y_train)
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Alcohol'], X_train_scaled['Malic acid'],c=y_train)
ax2.set_title("After Scaling")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(['Education_Level'], ax=ax1)
sns.kdeplot(X_train['Career_Readiness_Level'], ax=ax1)

# # after scaling
# ax2.set_title('After Standard Scaling')
# sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
# sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 # before scaling
#       4 ax1.set_title('Before Scaling')
# ----> 5 sns.kdeplot(['Education_Level'], ax=ax1)
#       6 sns.kdeplot(X_train['Career_Readiness_Level'], ax=ax1)
#       8 # # after scaling
#       9 # ax2.set_title('After Standard Scaling')
#      10 # sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
#      11 # sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
#      12 # plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/seaborn/distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
# ...

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Alcohol Distribution Before Scaling')
sns.kdeplot(df['Education_Level'], ax=ax1)

# after scaling
# ax2.set_title('Alcohol Distribution After Standard Scaling')
# sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Education_Level'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 5
# ...

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Malic acid Distribution Before Scaling')
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('Malic acid Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()
